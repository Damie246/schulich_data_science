# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/damie/Downloads/customers-1.csv")

# %%
df
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df=df.rename(columns={'id':'customer_id'})

# %%
df
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_name         13 non-null     object
#  1   num_products      13 non-null     int64
#  2   province          13 non-null     object
#  3   len_relationship  13 non-null     int64
#  4   cust_category     13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes

# %%
df.columns = ['Customers', 'Num_Products', 'Province', 'Relationship', 'Category']
df
# Out:
#                       Customers  Num_Products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1101                 James Dean             3       BC             3
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1585               Steven Prime             5       AB             2
# ...

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#                       Customers  Num_Products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1005         Mariah Anita Smith             2       BC             3
# 1006              Stephen Smith             5       ON             4
# 1008             Robert Optimus             3       MB            10
# 1014              Delilah Avery             2       AB             3
# 1101                 James Dean             3       BC             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1475          Stephanie Element             2       ON             5
# ...

# %%
df['Customers'].loc[1475]
# Out:
# 'Stephanie Element'

# %%
df['Customers'].iloc[-1]
# Out:
# 'Stephanie Element'

# %%
df[['Customers','Category']]
# Out:
#                       Customers          Category
# customer_id
# 1001             Johnny Awesome            wealth
# 1002                 Bob Marley  personal_banking
# 1004               Taylor Swift               hnw
# 1101                 James Dean            wealth
# 1006              Stephen Smith               hnw
# 1014              Delilah Avery  personal_banking
# 1254               Johnson Cory               hnw
# 1285                 Maria Alva            wealth
# 1354               Jessica Fast  personal_banking
# 1005         Mariah Anita Smith  personal_banking
# 1008             Robert Optimus               hnw
# 1585               Steven Prime            wealth
# 1475          Stephanie Element  personal_banking

# %%
df
# Out:
#                       Customers  Num_Products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1101                 James Dean             3       BC             3
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1585               Steven Prime             5       AB             2
# ...

# %%
df[(df['Province']=='ON') & (df['Category']=='personal_banking')]
# Out:
#                      Customers  Num_Products Province  Relationship
# customer_id
# 1002                Bob Marley             4       ON             1  \
# 1475         Stephanie Element             2       ON             5
#
#                      Category
# customer_id
# 1002         personal_banking
# 1475         personal_banking

# %%
df[df.Customers.str.lower().str.contains('h')]
# Out:
#                       Customers  Num_Products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1005         Mariah Anita Smith             2       BC             3
# 1475          Stephanie Element             2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1006                      hnw
# 1014         personal_banking
# 1254                      hnw
# 1005         personal_banking
# 1475         personal_banking

# %%
df.sort_values('Customers', ascending=True)
# Out:
#                       Customers  Num_Products Province  Relationship
# customer_id
# 1002                 Bob Marley             4       ON             1  \
# 1014              Delilah Avery             2       AB             3
# 1101                 James Dean             3       BC             3
# 1354               Jessica Fast             4       BC             5
# 1001             Johnny Awesome             3       ON             1
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1475          Stephanie Element             2       ON             5
# 1006              Stephen Smith             5       ON             4
# 1585               Steven Prime             5       AB             2
# ...

# %%
df_grouped=df.groupby('Province')

# %%
df_grouped.get_group('ON')
# Out:
#                      Customers  Num_Products Province  Relationship
# customer_id
# 1001            Johnny Awesome             3       ON             1  \
# 1002                Bob Marley             4       ON             1
# 1006             Stephen Smith             5       ON             4
# 1285                Maria Alva             5       ON             2
# 1475         Stephanie Element             2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1006                      hnw
# 1285                   wealth
# 1475         personal_banking

# %%
df_trans = pd.read_csv('/Users/damie/Downloads/transactions-1.csv')
df_trans.set_index('customer_id',inplace=True)

# %%
df_trans
# Out:
#              id txn_type  txn_total
# customer_id
# 1001          1    Debit     165.78
# 1001          2   Credit      42.10
# 1001          4   Credit     103.03
# 1001          5   Credit      56.60
# 1002          6    Debit     214.34
# 1002          7     Cash     115.69
# 1002          8    Debit      21.37
# 1004          9     Cash     227.58
# 1004         10   Credit       5.92
# 1006         11    Debit     225.89
# 1014         12     Cash      67.96
# 1254         13    Debit     235.79
# 1285         14     Cash     160.89
# 1354         15   Credit     377.26
# 1005         16    Debit     276.01
# 1008         17   Credit     190.02
# 1585         18    Debit     320.40
# 1475         19     Cash     328.72
# 1014         20    Debit     449.39
# 1254         21     Cash      15.26
# 1285         22   Credit     393.91
# 1354         23    Debit      94.32
# 1005         24    Debit     403.62
# 1008         25     Cash     242.73
# ...

# %%
df_merged = pd.merge(left=df_trans, right=df, left_on='customer_id', right_on='customer_id')

# %%
df_merged
# Out:
#              id txn_type  txn_total           Customers  Num_Products
# customer_id
# 1001          1    Debit     165.78      Johnny Awesome             3  \
# 1001          2   Credit      42.10      Johnny Awesome             3
# 1001          4   Credit     103.03      Johnny Awesome             3
# 1001          5   Credit      56.60      Johnny Awesome             3
# 1002          6    Debit     214.34          Bob Marley             4
# 1002          7     Cash     115.69          Bob Marley             4
# 1002          8    Debit      21.37          Bob Marley             4
# 1004          9     Cash     227.58        Taylor Swift             2
# 1004         10   Credit       5.92        Taylor Swift             2
# 1006         11    Debit     225.89       Stephen Smith             5
# 1014         12     Cash      67.96       Delilah Avery             2
# 1014         20    Debit     449.39       Delilah Avery             2
# ...
